# %%
import pandas as pd
# import numpy as np
# import nltk
import string
import re

# %%
#Read csv file
df = pd.read_excel('11_26_19_CTL.xlsx')

# %%
#My first method
# result = 'I understand you are chatting'
# if result.find('I understand you are chatting') ==-1:
#     print('No results found')
# else:
#     return result.find
# df.tail()

# %%
# str = "All Services"
# result = re.findall("Test_Data.csv", str)
# print(df.to_excel("Test_Data_Results.xlsx"))

# str= "High Speed Internet/Wi-Fi"
# x = re.search("\s", str)
# print("High Speed Internet/Wi-Fi", x.start())

# %%
#Matches a string with a colum and creates dataframe with results
df=df[df['response'].str.match("I understand you are chatting about problems with your service")]

# %%
#Checks for missing values & drops missing values
df.isnull().sum()
df.dropna()
# Out:
#                                                       _id  \
# 50241   H3928654246007349639-dfd57222d09d42b6a8711aa93...
# 50242   H3928654246007349639-dfd57222d09d42b6a8711aa93...
# 50243   H3928654246007349639-dfd57222d09d42b6a8711aa93...
# 50244   H3928654246007349639-dfd57222d09d42b6a8711aa93...
# 50245   H3928654246007349639-dfd57222d09d42b6a8711aa93...
# ...                                                   ...
# 543706  H4611666125013895302-4d732ff95a684537831590580...
# 543707  H4611666125013895302-4d732ff95a684537831590580...
# 543708  H4611666125013895302-4d732ff95a684537831590580...
# 543709  H4611666125013895302-4d732ff95a684537831590580...
# 543710  H4611666125013895302-4d732ff95a684537831590580...
#
#                        timestamp                           utteranceId  \
# 50241   2019-11-22T05:03:38.574Z  f5a8438f-2dd6-4c14-9abe-a2dad7e5eeee
# 50242   2019-11-22T05:03:38.574Z  f5a8438f-2dd6-4c14-9abe-a2dad7e5eeee
# ...

# %%
# #Write to an excel file
df.to_excel('Test_Data_Results.xlsx')
